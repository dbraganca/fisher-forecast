# %%
from resultsfuncs import *
from scipy.io import mmread
import matplotlib.pyplot as plt
# %matplotlib inline

fishers_path = 'Fishers/'
plots_path = 'plots/'

# %% [markdown]
# # Imports

# %% [markdown]
# ### BOSS imports

# %% [markdown]
# Full P results w/o 4 sky correlation

# %%
Pfull4sky = mmread(fishers_path + 'BOSS/Pfull4sky.mtx')
Pfullnoskycorr = mmread(fishers_path + 'BOSS/Pfullnoskycorr.mtx')

# %% [markdown]
# Full PB cross w/o 4 sky correlation

# %%
PBcross4sky = mmread(fishers_path + 'BOSS/PBcross4sky.mtx')
PBcrossnoskycorr = mmread(fishers_path + 'BOSS/PBcrossnoskycorr.mtx')

# %% [markdown]
# Numerical covariance Diagonals  w/o 4 sky correlation,  w/o B

# %%
PNumD4sky = mmread(fishers_path + 'BOSS/PNumD4sky.mtx')
PNumDnoskycorr = mmread(fishers_path + 'BOSS/PNumDnoskycorr.mtx')
PBNumD4sky = mmread(fishers_path + 'BOSS/PBNumD4sky.mtx')
PBNumDnoskycorr = mmread(fishers_path + 'BOSS/PBNumDnoskycorr.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
Panafullz = mmread(fishers_path + 'BOSS/Panafullz.mtx')
PBanafullz = mmread(fishers_path + 'BOSS/PBanafullz.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B no shot noise (full mu)

# %%
PanamufullzNS = mmread(fishers_path + 'BOSS/PanamufullzNS.mtx')
PBanamufullzNS = mmread(fishers_path + 'BOSS/PBanamufullzNS.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence full mu dependence,  w/o B

# %%
Panamufullz = mmread(fishers_path + 'BOSS/Panamufullz.mtx')
PBanamufullz = mmread(fishers_path + 'BOSS/PBanamufullz.mtx')

# %% [markdown]
# ### DESI Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
DPanafullz = mmread(fishers_path + 'DESI/Panafullz.mtx').real
DPBanafullz = mmread(fishers_path + 'DESI/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
DPanamufullz = mmread(fishers_path + 'DESI/Panamufullz.mtx').real
DPBanamufullz = mmread(fishers_path + 'DESI/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, 2loop,  w/o B

# %%
DPanamufullz2L = mmread(fishers_path + 'DESI/Panamufullz2L.mtx').real
DPBanamufullz2L = mmread(fishers_path + 'DESI/PBanamufullz2L.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B

# %%
DPBanamufullzT = mmread(fishers_path + 'DESI/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, NS,  w/o B

# %%
DPanamufullzNS = mmread(fishers_path + 'DESI/PanamufullzNS.mtx').real
DPBanamufullzNS = mmread(fishers_path + 'DESI/PBanamufullzNS.mtx').real

# %% [markdown]
# ### MegaMapper -optimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMoPanafullz = mmread(fishers_path + 'MMo/Panafullz.mtx').real
MMoPBanafullz = mmread(fishers_path + 'MMo/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMoPanamufullz = mmread(fishers_path + 'MMo/Panamufullz.mtx').real
MMoPBanamufullz = mmread(fishers_path + 'MMo/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMoPBanamufullzT = mmread(fishers_path + 'MMo/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMoPanamufullzNS = mmread(fishers_path + 'MMo/PanamufullzNS.mtx').real
MMoPBanamufullzNS = mmread(fishers_path + 'MMo/PBanamufullzNS.mtx').real

# %% [markdown]
# ### MegaMapper -pessimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMpPanafullz = mmread(fishers_path + 'MMp/Panafullz.mtx').real
MMpPBanafullz = mmread(fishers_path + 'MMp/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMpPanamufullz = mmread(fishers_path + 'MMp/Panamufullz.mtx').real
MMpPBanamufullz = mmread(fishers_path + 'MMp/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMpPBanamufullzT = mmread(fishers_path + 'MMp/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMpPanamufullzNS = mmread(fishers_path + 'MMp/PanamufullzNS.mtx').real
MMpPBanamufullzNS = mmread(fishers_path + 'MMp/PBanamufullzNS.mtx').real

# %% [markdown]
# ## BOSS Pipeline validation

# %% [markdown]
# Reduction to Diagonal Covariance and fits

# %%
getPlot([Pfull4sky,PNumDnoskycorr,Panafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P measured Covariance","P NumD","P Analytical"])
getPlot([PBcross4sky,PBNumDnoskycorr,PBanafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P+B measured Cov.","P+B measured Cov.diag. ","P+B analytical Cov.diag."],'plot/BOSS/PB_Diagvalidation')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# # Results

# %% [markdown]
# ## BOSS Results

# %% [markdown]
# ### Additional Parameters, with full numerical covariances

# %%
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plot/BOSS/test')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plot/BOSS/PBNum_extrans')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plot/BOSS/PBNum_extramn')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","Ok", "ob"]+biasindex,[ "h", "lnAs","Om","Ok"],["P","P +B"],'plot/BOSS/PBNum_extraOk')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Impact of higher multipoles and shot noise (with analytical covariance)

# %%
getPlot([Panafullz,Panamufullz,PBanafullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["$P_0+P_2$","$P^r$ full","$P_0+P_2+B_0$","$P^r+B^r$ full"],'plot/BOSS/highermulti')
getPlot([Panamufullz,PanamufullzNS,PBanamufullz,PBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plot/BOSS/shotnoise')
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [28.609982756409767, 25.086411761692958, 12.088003543513437]
# [271.2899508427384, 255.5161153658299, 149.4697760434271]
# [67.54635816827881, 65.4483774752885, 38.457937758954]

# %%
fnlerrors([PBanafullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanafullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanafullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [28.609982756409767]
# [271.2899508427384]
# [67.54635816827881]

# %%
fnlerrors([PBanafullz],["fNLloc"]+biasindex2,[ "fNLloc"])
fnlerrors([PBanafullz],["fNLeq"]+biasindex2,[ "fNLeq"])
fnlerrors([PBanafullz],["fNLorth"]+biasindex2,[ "fNLorth"])
# Out:
# [26.55939664018663]
# [265.02761298080014]
# [66.69765361985449]

# %%
samp1,cpar1,lb1 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plot/BOSS/biasfixns')

fnlerrors([PBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([PBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([PBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [4.78120501842688]
# [46.14035204478073]
# [26.61509660829464]

# %%
print(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.012022170466057198, 0.060585804033001116, 0.007933694339103346, 0.027649480333597775], [0.0051526486477837035, 0.024544640184851717, 0.0039006897210057106, 0.012301819823823237]]
# Removed no burn in
# Removed no burn in
# [[0.013778436516467532, 0.1719428329112522, 0.012786682405869316, 0.07172610092398861], [0.006059704012348415, 0.061681253691818566, 0.006069819036238143, 0.02849298872345582]]

# %% [markdown]
# ## DESI Results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([DPanamufullz,DPBanamufullz],
        ["lnAs", "h", "Om" ,"ob"]+biasindex,
        [ "h", "lnAs","Om"],
        ["P","P +B"],
        plots_path + 'DESI/PB_base')
getPlot([DPanamufullz,DPBanamufullz],
        ["lnAs", "h", "Om","ns", "ob"]+biasindex,
        [ "h", "lnAs","Om","ns"],
        ["P","P +B"],
        plots_path + 'DESI/PB_extrans')
getPlot([DPanamufullz,DPBanamufullz],
        ["lnAs", "h", "Om","mn", "ob"]+biasindex,
        [ "h", "lnAs","Om","mn"],
        ["P","P +B"],
        plots_path + 'DESI/PB_extramn')
getPlot([DPanamufullz,DPBanamufullz],
        ["lnAs", "h", "Om","Ok", "ob"]+biasindex,
        [ "h", "lnAs","Om","Ok"],
        ["P","P +B"],
        plots_path + 'DESI/PB_extraOk')

fnlerrors([DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.480748395328266]
# [161.293080888998]
# [46.146487007285806]

# %%
fnlerrors([DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
print(1)
fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
print(2)
fnlerrors([DPBanamufullz],["fNLloc","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLorth"])
# Out:
# [3.386352879221664]
# [127.18524063287828]
# [35.67226924369422]
# 1
# [2.036546464900119]
# [22.19853220905541]
# [11.92224817996626]
# 2
# [3.5448288261028416]
# [128.1698660425739]
# [35.833161031552535]

# %% [markdown]
# ### Shotnoise impact

# %%
getPlot([DPanamufullz,DPBanamufullz,DPanamufullzNS,DPBanamufullzNS],["lnAs", "h", "Om","ns" ,"ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B",r"P: $n_b \rightarrow\infty$",r"P+B: $n_b \rightarrow\infty$"],'plot/DESI/PB_NS')
fnlerrors([DPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [1.622888023153965]
# [75.5704103720143]
# [18.616551366977955]

# %% [markdown]
# ### 2 Loop P impact

# %%
getPlot([DPBanamufullz,DPBanamufullz2L],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P +B","P 2L +B"],'plot/DESI/PB_2L')
fnlerrors([DPBanamufullz2L],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz2L],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz2L],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [3.3498253179619244]
# [124.22780094598292]
# [35.445389107328886]

# %% [markdown]
# ### Tree comparison

# %%
getPlot([DPBanamufullzT,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plot/DESI/PB_extrans_Tree')
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [3.46874456137081, 3.386352879221664]
# [116.20214164566164, 127.18524063287828]
# [59.66116669929931, 35.67226924369422]

# %% [markdown]
# ### Fixed Bias

# %%
print(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [[0.004266488592010813, 0.02196692081364659, 0.003312205579256802, 0.011333207941207063], [0.0023565206362046965, 0.011281579776288997, 0.001855930024172318, 0.0062362097331509405]]
# Removed no burn in
# Removed no burn in
# [[0.0049697858765826546, 0.0481823608226931, 0.004620065925275928, 0.024830486361695096], [0.002629582772255242, 0.023702302690469763, 0.002450700725524821, 0.012117932147438587]]
# [2.036546464900119]
# [22.19853220905541]
# [11.92224817996626]

# %% [markdown]
# ## MegaMapper optimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plot/MMo/PB_base')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plot/MMo/PB_extrans')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plot/MMo/PB_extramn')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","Ok", "ob"]+biasindex,[ "h", "lnAs","Om","Ok"],["P","P +B"],'plot/MMo/PB_extraOk')

fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2633710795280351]
# [18.499246702793474]
# [5.4960158811061035]

# %%
fnlerrors([MMoPBanamufullz,MMoPBanamufullzT],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullzT],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullzT],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [0.2633710795280351, 0.27391243570512924]
# [18.499246702793474, 17.161088352086153]
# [5.4960158811061035, 7.86515644940848]

# %%
fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindex2,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindex2,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindex2,[ "fNLorth"])
# Out:
# [0.2622203878519631]
# [18.185318360427804]
# [5.4023194749699215]

# %% [markdown]
# ### Shot Noise impact and bias impact

# %%
getPlot([MMoPanamufullz,MMoPanamufullzNS,MMoPBanamufullz,MMoPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plot/MMo/shotnoise')
fnlerrors([MMoPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.09167600010364296]
# [4.43777718843212]
# [1.4096593252917344]

# %%
samp1,cpar1,lb1 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plot/MMo/biasfixns')

fnlerrors([MMoPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.1631541242480881]
# [3.4741101501758673]
# [1.6602935125745666]

# %%
print(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
fnlerrors([MMoPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [[0.0009556184017875618, 0.005180195156966548, 0.0006463475394840942, 0.0019265188859476706], [0.00040000650494504347, 0.001364585227444053, 0.00012612385010351857, 0.00044022555792935797]]
# Removed no burn in
# Removed no burn in
# [[0.0012808983842975976, 0.010634640472761206, 0.0010328545088737677, 0.004659709868436102], [0.00046006478582230837, 0.0025884801932126804, 0.0002837181425829113, 0.0011103476736248447]]
# [0.1631541242480881]
# [3.4741101501758673]
# [1.6602935125745666]

# %% [markdown]
# ### Tree comparison

# %%
getPlot([MMoPBanamufullzT,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plot/MMo/PB_extrans_Tree')
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [0.27391243570512924, 0.2633710795280351]
# [17.161088352086153, 18.499246702793474]
# [7.86515644940848, 5.4960158811061035]

# %% [markdown]
# ## MegaMapper pesimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plot/MMp/PB_base')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plot/MMp/PB_extrans')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plot/MMp/PB_extramn')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","Ok", "ob"]+biasindex,[ "h", "lnAs","Om","Ok"],["P","P +B"],'plot/MMp/PB_extraOk')

fnlerrors([MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.42573899407271887]
# [32.5101772109257]
# [9.610340436420236]

# %%
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [0.2633710795280351, 0.42573899407271887]
# [18.499246702793474, 32.5101772109257]
# [5.4960158811061035, 9.610340436420236]

# %% [markdown]
# ### Shot Noise and bias impact

# %%
getPlot([MMpPanamufullz,MMpPanamufullzNS,MMpPBanamufullz,MMpPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plot/MMp/shotnoise')
fnlerrors([MMpPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMpPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMpPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.11402777578124557]
# [6.73355140361875]
# [1.63680594584622]

# %%
samp1,cpar1,lb1 = getSamps([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plot/MMp/biasfixns')

fnlerrors([MMpPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2893630858720153]
# [6.24507260922775]
# [3.0208147639320275]

# %%
print(getError([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
fnlerrors([MMpPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [[0.0014229177414571846, 0.007476096081932941, 0.001143374324384056, 0.003368836418347502], [0.0005625293667743602, 0.00218172644204628, 0.0003310847607658721, 0.0009104060271336468]]
# Removed no burn in
# Removed no burn in
# [[0.0017625030081510015, 0.015895145944894534, 0.0016466660614800996, 0.007650985571706131], [0.0006414192594365489, 0.0042400401299170255, 0.0005023399439096941, 0.0020705101335287764]]
# [0.2893630858720153]
# [6.24507260922775]
# [3.0208147639320275]

# %% [markdown]
# ### Tree Comparison

# %%
getPlot([MMpPBanamufullzT,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plot/MMp/PB_extrans_Tree')
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [0.4342676878972348, 0.42573899407271887]
# [29.67792891655795, 32.5101772109257]
# [14.046317763641124, 9.610340436420236]
