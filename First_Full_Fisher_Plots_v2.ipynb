# %%
from resultsfuncs import *
from scipy.io import mmread
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3],[1,2,3])
plt.show()

# %% [markdown]
# # Imports

# %% [markdown]
# ### BOSS imports

# %% [markdown]
# Full P results w/o 4 sky correlation

# %%
Pfull4sky = mmread('Fishers2/BOSS/Pfull4sky.mtx')
Pfullnoskycorr = mmread('Fishers2/BOSS/Pfullnoskycorr.mtx')

# %% [markdown]
# Full PB cross w/o 4 sky correlation

# %%
PBcross4sky = mmread('Fishers2/BOSS/PBcross4sky.mtx')
PBcrossnoskycorr = mmread('Fishers2/BOSS/PBcrossnoskycorr.mtx')

# %% [markdown]
# Numerical covariance Diagonals  w/o 4 sky correlation,  w/o B

# %%
PNumD4sky = mmread('Fishers2/BOSS/PNumD4sky.mtx')
PNumDnoskycorr = mmread('Fishers2/BOSS/PNumDnoskycorr.mtx')
PBNumD4sky = mmread('Fishers2/BOSS/PBNumD4sky.mtx')
PBNumDnoskycorr = mmread('Fishers2/BOSS/PBNumDnoskycorr.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
Panafullz = mmread('Fishers2/BOSS/Panafullz.mtx')
PBanafullz = mmread('Fishers2/BOSS/PBanafullz.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B no shot noise (full mu)

# %%
PanamufullzNS = mmread('Fishers2/BOSS/PanamufullzNS.mtx')
PBanamufullzNS = mmread('Fishers2/BOSS/PBanamufullzNS.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence full mu dependence,  w/o B

# %%
Panamufullz = mmread('Fishers2/BOSS/Panamufullz.mtx')
PBanamufullz = mmread('Fishers2/BOSS/PBanamufullz.mtx')

# %% [markdown]
# ### DESI Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
DPanafullz = mmread('Fishers2/DESI/Panafullz.mtx').real
DPBanafullz = mmread('Fishers2/DESI/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
DPanamufullz = mmread('Fishers2/DESI/Panamufullz.mtx').real
DPBanamufullz = mmread('Fishers2/DESI/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, 2loop,  w/o B

# %%
DPanamufullz2L = mmread('Fishers2/DESI/Panamufullz2L.mtx').real
DPBanamufullz2L = mmread('Fishers2/DESI/PBanamufullz2L.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B

# %%
DPBanamufullzT = mmread('Fishers2/DESI/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, NS,  w/o B

# %%
DPanamufullzNS = mmread('Fishers2/DESI/PanamufullzNS.mtx').real
DPBanamufullzNS = mmread('Fishers2/DESI/PBanamufullzNS.mtx').real

# %% [markdown]
# ### MegaMapper -optimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMoPanafullz = mmread('Fishers2/MMo/Panafullz.mtx').real
MMoPBanafullz = mmread('Fishers2/MMo/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMoPanamufullz = mmread('Fishers2/MMo/Panamufullz.mtx').real
MMoPBanamufullz = mmread('Fishers2/MMo/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMoPBanamufullzT = mmread('Fishers2/MMo/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMoPanamufullzNS = mmread('Fishers2/MMo/PanamufullzNS.mtx').real
MMoPBanamufullzNS = mmread('Fishers2/MMo/PBanamufullzNS.mtx').real

# %% [markdown]
# ### MegaMapper -pessimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMpPanafullz = mmread('Fishers/MMp/Panafullz.mtx').real
MMpPBanafullz = mmread('Fishers/MMp/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMpPanamufullz = mmread('Fishers/MMp/Panamufullz.mtx').real
MMpPBanamufullz = mmread('Fishers/MMp/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMpPanamufullzT = mmread('Fishers/MMp/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMpPanamufullzNS = mmread('Fishers/MMp/PanamufullzNS.mtx').real
MMpPBanamufullzNS = mmread('Fishers/MMp/PBanamufullzNS.mtx').real

# %% [markdown]
# ## BOSS Pipeline validation

# %% [markdown]
# Reduction to Diagonal Covariance and fits

# %%
getPlot([Pfull4sky,PNumDnoskycorr,Panafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P measured Covariance","P NumD","P Analytical"])
getPlot([PBcross4sky,PBNumDnoskycorr,PBanafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P+B measured Cov.","P+B measured Cov.diag. ","P+B analytical Cov.diag."],'plots2/BOSS/PB_Diagvalidation')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# # Results

# %% [markdown]
# ## BOSS Results

# %% [markdown]
# ### Additional Parameters, with full numerical covariances

# %%
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plots2/BOSS/test')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plots2/BOSS/PBNum_extrans')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plots2/BOSS/PBNum_extramn')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Impact of higher multipoles and shot noise (with analytical covariance)

# %%
getPlot([Panafullz,Panamufullz,PBanafullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["$P_0+P_2$","$P^r$ full","$P_0+P_2+B_0$","$P^r+B^r$ full"],'plots2/BOSS/highermulti')
getPlot([Panamufullz,PanamufullzNS,PBanamufullz,PBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plots2/BOSS/shotnoise')
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [32.3658286946635, 28.373704468163073, 13.491898421122194]
# [316.3520788945215, 299.2818536993924, 175.6080474488959]
# [80.87213045504645, 78.37554300693738, 44.55141114178122]

# %%
fnlerrors([PBanafullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanafullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanafullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [32.36582869466521]
# [316.35207889453346]
# [80.8721304550497]

# %%
fnlerrors([PBanafullz],["fNLloc"]+biasindex2,[ "fNLloc"])
fnlerrors([PBanafullz],["fNLeq"]+biasindex2,[ "fNLeq"])
fnlerrors([PBanafullz],["fNLorth"]+biasindex2,[ "fNLorth"])
# Out:
# [30.175004191573922]
# [308.980062079111]
# [80.04952371813552]

# %%
316.3/309.0
# Out:
# 1.0236245954692558

# %%
samp1,cpar1,lb1 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plots2/BOSS/biasfixns')

fnlerrors([PBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([PBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([PBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [5.658537304897864]
# [55.44470928014992]
# [32.126725575693]

# %%
print(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.012740488439128688, 0.06534750026711801, 0.008534891472730994, 0.029553114544259032], [0.005565564964514423, 0.026900685691892395, 0.004180173847950937, 0.013380479681419014]]
# Removed no burn in
# Removed no burn in
# [[0.014598012428646296, 0.18433606814318565, 0.01362459513800541, 0.0767038843160782], [0.006450796130599286, 0.06595437520311506, 0.0063467213237342664, 0.030001429370243228]]

# %% [markdown]
# ## DESI Results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plots2/DESI/PB_base')
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plots2/DESI/PB_extrans')
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plots2/DESI/PB_extramn')
fnlerrors([DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [8.32447388520836]
# [132.58118715078066]
# [37.491225204720635]

# %%
fnlerrors([DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
print(1)
fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
print(2)
fnlerrors([DPBanamufullz],["fNLloc","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLorth"])
# Out:
# [8.324473885208446]
# [132.58118715078356]
# [37.491225204720465]
# 1
# [2.557791101356673]
# [23.34749556195989]
# [12.514482225537767]
# 2
# [11.023493013161094]
# [133.62033821412507]
# [37.67210551062355]

# %% [markdown]
# ### Shotnoise impact

# %%
getPlot([DPanamufullz,DPBanamufullz,DPanamufullzNS,DPBanamufullzNS],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B","P NS","P +B NS"],'plots2/DESI/PB_NS')
fnlerrors([DPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [4.347852964847209]
# [79.05112185111822]
# [19.42146088704195]

# %% [markdown]
# ### 2 Loop P impact

# %%
getPlot([DPBanamufullz,DPBanamufullz2L],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P +B","P 2L +B"],'plots2/DESI/PB_2L')
fnlerrors([DPBanamufullz2L],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz2L],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz2L],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [7.909610992721223]
# [129.55157593829915]
# [37.25672537557807]

# %% [markdown]
# ## MegaMapper optimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plots2/MMo/PB_base')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plots2/MMo/PB_extrans')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plots2/MMo/PB_extramn')
fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.872375320815846]
# [28.771154388775578]
# [7.90437146107768]

# %%
fnlerrors([MMoPBanamufullz,MMoPBanamufullzT],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullzT],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullzT],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [0.872375320815846, 1.0610515779272174]
# [28.771154388775578, 29.75891034502435]
# [7.90437146107768, 13.751435876561203]

# %%
fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindex2,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindex2,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindex2,[ "fNLorth"])
# Out:
# [0.8708594014527536]
# [28.605773645625018]
# [7.876815949137298]

# %% [markdown]
# ### Shot Noise impact and bias impact

# %%
getPlot([MMoPanamufullz,MMoPanamufullzNS,MMoPBanamufullz,MMoPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plots2/MMo/shotnoise')
fnlerrors([MMoPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.17068600346372534]
# [7.31064332640032]
# [1.9268224208308153]

# %%
samp1,cpar1,lb1 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plots2/MMo/biasfixns')

fnlerrors([MMoPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.3090720016333964]
# [5.21079898137955]
# [2.4716104813764552]

# %%
print(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.0012158492242501254, 0.006660010993051995, 0.0010076671560741532, 0.002816937832083468], [0.0005146263096794897, 0.0020005842475907323, 0.00028608498744013626, 0.0008010268627517909]]
# Removed no burn in
# Removed no burn in
# [[0.0015349809957250914, 0.013829876845567024, 0.0014419325278731583, 0.006823331122550707], [0.0005870541549422174, 0.003913650394654361, 0.0004480517878306301, 0.0018564399916050677]]

# %% [markdown]
# ## MegaMapper pesimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plots2/MMp/PB_base')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plots2/MMp/PB_extrans')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plots2/MMo/PB_extramn')
fnlerrors([MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [2.7004095885000226]
# [65.43915536370953]
# [19.340329068532665]

# %%
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [1.1479105032497574, 1.5769264289367944]
# [36.28638303301874, 54.273203926086516]
# [9.884401989227884, 15.864378559787498]

# %% [markdown]
# ### Shot Noise impact
